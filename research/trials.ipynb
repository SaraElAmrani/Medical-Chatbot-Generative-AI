# %%
print("OK")
# Out:
# The kernel failed to start as the Python Environment 'medicalChatbot (Python -1.-1.-1)' is no longer available. Consider selecting another kernel or refreshing the list of Python Environments.
